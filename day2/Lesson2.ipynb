# %%
import numpy as np
import pandas as pd

# %%
a = 0

for i in range(10):
    a = a + i

print(a)
# Out:
# 45

# %%
a=[1,3,4,5,6,7]
b=[5,6,7,5,4,2]

# %%
a+b
# Out:
# [1, 3, 4, 5, 6, 7, 5, 6, 7, 5, 4, 2]

# %%
c=[a[i]+b[i] for i in range(len(a)) if a[i]+b[i]!=11]

# %%
c
# Out:
# [6, 9, 10, 10, 9]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\szhak\\AppData\\Local\\Programs\\anaconda-desktop\\YDL 2026'

# %%
from pathlib import Path

Path("Lesson2.ipynb").resolve()
# Out:
# WindowsPath('C:/Users/szhak/AppData/Local/Programs/anaconda-desktop/YDL 2026/Lesson2.ipynb')
